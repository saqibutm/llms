# %%
# !curl -H "Authorization: Bearer $api_key" http://ai.uaf.edu.pk/api/models
# Out:
# {"data":[{"id":"deepseek-r1:32b","name":"deepseek-r1:32b","object":"model","created":1740970468,"owned_by":"ollama","ollama":{"name":"deepseek-r1:32b","model":"deepseek-r1:32b","modified_at":"2025-01-29T08:02:38.173779+05:00","size":19851337640,"digest":"38056bbcbb2d068501ecb2d5ea9cea9dd4847465f1ab88c4d4a412a9f7792717","details":{"parent_model":"","format":"gguf","family":"qwen2","families":["qwen2"],"parameter_size":"32.8B","quantization_level":"Q4_K_M"},"urls":[0]},"info":{"id":"deepseek-r1:32b","user_id":"ef7d8662-9753-40f5-bf26-8dc7d3e5fd85","base_model_id":null,"name":"deepseek-r1:32b","params":{},"meta":{"profile_image_url":"/static/favicon.png","description":null,"capabilities":{"vision":true,"citations":true},"suggestion_prompts":null,"tags":[]},"access_control":null,"is_active":true,"updated_at":1738598386,"created_at":1738570895},"actions":[]},{"id":"llama3.2-vision:latest","name":"Kisan360 AI","object":"model","created":1740970468,"owned_by":"ollama","ollama":{"name":"llam
# ...

# %%
from utils import llama
# Example usage
response = llama("What is precision agriculture?", verbose=True)
print("\nLLaMA Response:\n", response)
# Out:
# Prompt:
# What is precision agriculture?
#
# Model: llama3.2-vision:latest
#
# LLaMA Response:
#  Precision agriculture, also known as precision farming or precision ag, refers to the use of advanced technologies and data analysis to optimize crop yields, reduce waste, and improve resource efficiency in agricultural production.
#
# The core principles of precision agriculture involve using a combination of sensors, GPS, drones, satellite imaging, and other digital tools to collect and analyze detailed information about soil type, moisture levels, temperature, humidity, and other environmental factors. This data is then used to make informed decisions about planting, irrigation, fertilization, pest management, and harvesting.
#
# Some key features of precision agriculture include:
#
# 1. **Site-specific farming**: tailoring agricultural practices to specific areas within a field based on detailed soil and environmental analysis.
# ...

# %%
# define the prompt
prompt = "Help me write a birthday card for my dear friend Andrew."
response = llama(prompt)
print(response)
# Out:
# I'd be happy to help you write a birthday card for your friend Andrew.
#
# To get started, can you tell me a bit about Andrew and what kind of relationship you have with him? For example:
#
# * What's his personality like?
# * What are some fun memories or inside jokes that you share?
# * Is there something specific you'd like to say or celebrate about him on his birthday?
#
# Also, what's the tone you're aiming for in the card? Do you want it to be:
#
# * Funny and lighthearted
# * Heartfelt and sentimental
# * Inspirational or motivational
#
# Let me know and I can help you craft a birthday message that's just right for Andrew!
